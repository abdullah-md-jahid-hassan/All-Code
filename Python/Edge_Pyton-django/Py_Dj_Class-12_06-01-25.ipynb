# %%
import matplotlib.pyplot as plt
import pandas as pd
from tkinter.simpledialog import askinteger
from tkinter import *
from tkinter import messagebox

# %%
#Create csv For X and Y value
#Read csv
#Data set to list
# Creat graph line or scatter

# %%
all_data = pa.read_csv('Py_Dj_Class-12_06-01-25.csv') # read CSV
# Take the CGPA only as list
cgpa = data['X'].tolist()
y = data['Y'].tolist()
plt.scatter(x, y, label="Scatter", marker=".", color="green")
#plt.plot(x, y, label="Line", color="red")
#plt.pie(x)
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Scatter")
plt.legend()
plt.show()

# %%
#Libary - tkinter

# %%
top = tk.Tk()
top.geometry("100x100")
def show():
    num = askinteger("Input", "Input an Integer")
    print(num)

B = Button(top, text="Click", command=show)
B.place(x=50, y=50)
top.mainloop()
# Out:
# None
# None
